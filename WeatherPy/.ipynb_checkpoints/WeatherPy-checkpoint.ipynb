# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from scipy import stats

# %%
from api_keys import weather_api_key
from citipy import citipy

# %% [markdown]
# # General Cities List

# %%
output_data_file = "output_data/cities.csv"
cities_wth = pd.read_csv(output_data_file)
cities_wth
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]

# %%
lat_range =(-90,90)
lng_range =(-180,180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.00, high=90.00, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 627

# %% [markdown]
# # API Call

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

#city_name = cities_wth["City"].tolist()

lat = []
lng = []
hum = []
contr = []
name = []
date = []
max_temp = []
wd_sp = []
cld = []

#print(json.dumps(response,indent=4))

for city in cities:
    try:
        print(f"Processing {city}.")
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        hum.append(response['main']['humidity'])
        contr.append(response['sys']['country'])
        name.append(response['name'])
        date.append(response['dt'])
        max_temp.append(response['main']['temp_max'])
        wd_sp.append(response['wind']['speed'])
        cld.append(response['clouds']['all'])
    except (KeyError):
        print("City no found. Skipping..")
# Out:
# Processing torbay.
# Processing avarua.
# Processing hasaki.
# Processing new norfolk.
# Processing san patricio.
# Processing port alfred.
# Processing clarksville.
# Processing bluff.
# Processing hobart.
# Processing norman wells.
# Processing harper.
# Processing severo-kurilsk.
# Processing nanortalik.
# Processing punta arenas.
# Processing khatanga.
# Processing dikson.
# Processing acapulco.
# Processing wilmington.
# Processing hermanus.
# Processing illoqqortoormiut.
# City no found. Skipping..
# Processing waddan.
# Processing ushuaia.
# Processing ancud.
# Processing lompoc.
# Processing tuktoyaktuk.
# Processing yellowknife.
# Processing mar del plata.
# Processing bethel.
# Processing juneau.
# Processing kapaa.
# Processing nelson bay.
# Processing attawapiskat.
# City no found. Skipping..
# Processing oranjemund.
# Processing hithadhoo.
# Processing cabo san lucas.
# Processing hilo.
# Processing acajutla.
# Processing minas.
# Processing odweyne.
# City no found. Skipping..
# Processing qaanaaq.
# Processing taolanaro.
# City no found. Skipping..
# Processing albany.
# Processing egvekinot.
# Processing busselton.
# Processing mananjary.
# Processing ulaangom.
# Processing la ronge.
# Processing yeppoon.
# Processing barentsburg.
# City no found. Skipping..
# Processing alekseyevka.
# Processing vila velha.
# Processing mahebourg.
# Processing koslan.
# Processing airai.
# Processing gonaives.
# Processing port-gentil.
# Processing bredasdorp.
# Processing tiksi.
# Processing cidreira.
# Processing bac lieu.
# City no found. Skipping..
# Processing samarinda.
# Processing kavaratti.
# Processing kautokeino.
# Processing hobyo.
# Processing belushya guba.
# City no found. Skipping..
# Processing tabialan.
# City no found. Skipping..
# Processing barrow.
# Processing sur.
# Processing kaitangata.
# Processing chokurdakh.
# Processing geraldton.
# Processing panguipulli.
# Processing miri.
# Processing arraial do cabo.
# Processing teya.
# Processing cape town.
# Processing katsuura.
# Processing tutoia.
# Processing rio gallegos.
# Processing dakar.
# Processing rikitea.
# Processing amderma.
# City no found. Skipping..
# Processing lasa.
# Processing mataura.
# Processing skjervoy.
# Processing victoria.
# Processing bathsheba.
# Processing yian.
# City no found. Skipping..
# Processing leningradskiy.
# Processing nizhneyansk.
# City no found. Skipping..
# Processing lucea.
# Processing hualmay.
# Processing adrar.
# Processing vaitupu.
# City no found. Skipping..
# Processing castro.
# Processing butaritari.
# Processing grand forks.
# Processing basco.
# Processing nosy varika.
# Processing sayyan.
# Processing ribeira grande.
# Processing daitari.
# Processing lata.
# Processing pacific grove.
# Processing birecik.
# Processing vilhena.
# Processing vaini.
# Processing the valley.
# Processing goderich.
# Processing uvinza.
# Processing atuona.
# Processing alice springs.
# Processing caudry.
# Processing santa isabel do rio negro.
# Processing avera.
# Processing husavik.
# Processing kruisfontein.
# Processing walvis bay.
# Processing puerto ayora.
# Processing cayenne.
# Processing jamestown.
# Processing hamilton.
# Processing fenoarivo.
# Processing umzimvubu.
# City no found. Skipping..
# Processing porto novo.
# Processing lavrentiya.
# Processing tomatlan.
# Processing la libertad.
# Processing sinnamary.
# Processing singaparna.
# Processing east london.
# Processing almaznyy.
# Processing ahipara.
# Processing eyl.
# Processing anadyr.
# Processing lavumisa.
# Processing dhidhdhoo.
# Processing saint-augustin.
# Processing kegayli.
# City no found. Skipping..
# Processing port elizabeth.
# Processing yulara.
# Processing barahona.
# Processing bairiki.
# City no found. Skipping..
# Processing chuy.
# Processing touros.
# Processing hunchun.
# Processing tasiilaq.
# Processing kahului.
# Processing nishihara.
# Processing longyearbyen.
# Processing barra patuca.
# Processing jaisalmer.
# Processing bangui.
# Processing windsor.
# Processing cheyenne.
# Processing tasbuget.
# City no found. Skipping..
# Processing saint-francois.
# Processing te anau.
# Processing mayo.
# Processing pimenta bueno.
# Processing georgetown.
# Processing koumac.
# Processing saleaula.
# City no found. Skipping..
# Processing olinda.
# Processing venosa.
# Processing valparaiso.
# Processing tuatapere.
# Processing susehri.
# Processing makubetsu.
# Processing brae.
# Processing pimentel.
# Processing nguiu.
# City no found. Skipping..
# Processing grand river south east.
# City no found. Skipping..
# Processing tumannyy.
# City no found. Skipping..
# Processing ust-maya.
# Processing saint george.
# Processing raahe.
# Processing okmulgee.
# Processing tandur.
# Processing ozernovskiy.
# Processing mrirt.
# City no found. Skipping..
# Processing atar.
# Processing colonia.
# Processing hofn.
# Processing riyadh.
# Processing itzehoe.
# Processing grindavik.
# Processing mount gambier.
# Processing ayios kirikos.
# City no found. Skipping..
# Processing miandrivazo.
# Processing provideniya.
# Processing baculin.
# Processing caravelas.
# Processing kodiak.
# Processing zapolyarnyy.
# Processing poum.
# Processing kaeo.
# Processing thompson.
# Processing monrovia.
# Processing karla.
# Processing esperance.
# Processing tual.
# Processing chibombo.
# Processing martapura.
# Processing palmer.
# Processing guerrero negro.
# Processing ostashkov.
# Processing casper.
# Processing beringovskiy.
# Processing dongfeng.
# Processing utiroa.
# City no found. Skipping..
# Processing khagrachari.
# City no found. Skipping..
# Processing kulhudhuffushi.
# Processing vardo.
# Processing nyurba.
# Processing fuerte olimpo.
# Processing ilulissat.
# Processing naze.
# Processing barawe.
# City no found. Skipping..
# Processing chatra.
# Processing namibe.
# Processing maceio.
# Processing faya.
# Processing mildura.
# Processing sao jose da coroa grande.
# Processing mangochi.
# Processing trelew.
# Processing sihora.
# Processing agucadoura.
# Processing la rioja.
# Processing neutraubling.
# Processing teguise.
# Processing clyde river.
# Processing klaksvik.
# Processing mehamn.
# Processing saldanha.
# Processing alta floresta.
# Processing plainview.
# Processing vagur.
# Processing lebu.
# Processing chisec.
# Processing samusu.
# City no found. Skipping..
# Processing hirara.
# Processing develi.
# Processing souillac.
# Processing zheleznodorozhnyy.
# Processing santiago.
# Processing namatanai.
# Processing havelock.
# Processing porto velho.
# Processing plettenberg bay.
# Processing kerman.
# Processing labuan.
# Processing yaan.
# Processing presidencia roque saenz pena.
# Processing tura.
# Processing ust-koksa.
# Processing paradwip.
# City no found. Skipping..
# Processing batagay-alyta.
# Processing iskateley.
# Processing angoche.
# Processing thilogne.
# City no found. Skipping..
# Processing ponta do sol.
# Processing praia da vitoria.
# Processing gat.
# Processing salalah.
# Processing lima.
# Processing daud khel.
# Processing banjar.
# Processing san carlos de bariloche.
# Processing kamiiso.
# Processing kloulklubed.
# Processing ban dung.
# Processing kirkuk.
# Processing chegdomyn.
# Processing maracai.
# Processing sao joao da barra.
# Processing deder.
# Processing ithaca.
# Processing parrsboro.
# Processing khani.
# Processing desaguadero.
# Processing tunduru.
# City no found. Skipping..
# Processing kudahuvadhoo.
# Processing sebezh.
# Processing luderitz.
# Processing talakan.
# Processing agirish.
# Processing dunedin.
# Processing andrews.
# Processing onega.
# Processing kolokani.
# Processing san carlos.
# Processing south venice.
# Processing buala.
# Processing cherskiy.
# Processing banda aceh.
# Processing saint-joseph.
# Processing wattegama.
# Processing los llanos de aridane.
# Processing bandarbeyla.
# Processing veraval.
# Processing mehran.
# Processing tabriz.
# Processing saskylakh.
# Processing silver city.
# Processing townsville.
# Processing morondava.
# Processing jinchang.
# Processing matara.
# Processing ixtapa.
# Processing roma.
# Processing halalo.
# City no found. Skipping..
# Processing dolores.
# Processing pospelikha.
# Processing lorengau.
# Processing sorland.
# Processing taoudenni.
# Processing muros.
# Processing port augusta.
# Processing fortuna.
# Processing araouane.
# Processing nikolskoye.
# Processing thessalon.
# Processing saint anthony.
# Processing hermiston.
# Processing port hardy.
# Processing camacha.
# Processing nuuk.
# Processing usolye.
# Processing khandyga.
# Processing alofi.
# Processing gusinoye ozero.
# Processing agaro.
# Processing rungata.
# City no found. Skipping..
# Processing inuvik.
# Processing guanica.
# Processing itamaraca.
# Processing dana point.
# Processing strezhevoy.
# Processing amparafaravola.
# Processing velingara.
# Processing bilibino.
# Processing formosa do rio preto.
# Processing kavieng.
# Processing stephenville.
# Processing padang.
# Processing galdar.
# Processing zhaocheng.
# City no found. Skipping..
# Processing kismayo.
# City no found. Skipping..
# Processing meyungs.
# City no found. Skipping..
# Processing grants.
# Processing hit.
# Processing merauke.
# Processing medea.
# Processing barentu.
# Processing biak.
# Processing rognan.
# Processing arlit.
# Processing paita.
# Processing kataysk.
# Processing saint-georges.
# Processing valverde del camino.
# Processing tigil.
# Processing champerico.
# Processing amahai.
# Processing mecca.
# Processing buchanan.
# Processing alexandria.
# Processing sabang.
# Processing osecina.
# Processing ihosy.
# Processing pravda.
# Processing parga.
# Processing boa vista.
# Processing san policarpo.
# Processing portland.
# Processing hudson bay.
# Processing tena.
# Processing grand gaube.
# Processing constitucion.
# Processing deputatskiy.
# Processing road town.
# Processing paka.
# Processing cervo.
# Processing lamu.
# Processing waipawa.
# Processing mangai.
# Processing marsa matruh.
# Processing batagay.
# Processing nenjiang.
# Processing iqaluit.
# Processing smirnykh.
# Processing coihaique.
# Processing bekhtery.
# Processing bouna.
# Processing sobradinho.
# Processing hambantota.
# Processing miles city.
# Processing juifang.
# City no found. Skipping..
# Processing farmington.
# Processing tahe.
# Processing honiara.
# Processing silkeborg.
# Processing nyazepetrovsk.
# Processing warangal.
# Processing le cannet.
# Processing saint-philippe.
# Processing peniche.
# Processing prainha.
# Processing gangotri.
# City no found. Skipping..
# Processing roald.
# Processing nortelandia.
# Processing karamay.
# City no found. Skipping..
# Processing newtownards.
# Processing yumen.
# Processing belen.
# Processing yar-sale.
# Processing upernavik.
# Processing itarema.
# Processing korablino.
# Processing mys shmidta.
# City no found. Skipping..
# Processing kijang.
# Processing abilene.
# Processing babaeski.
# Processing coquimbo.
# Processing funtua.
# Processing kamenskoye.
# City no found. Skipping..
# Processing liepaja.
# Processing baruun-urt.
# Processing prince albert.
# Processing chagda.
# City no found. Skipping..
# Processing tilichiki.
# Processing kartuzy.
# Processing nome.
# Processing erzin.
# Processing rocha.
# Processing nyborg.
# Processing bengkulu.
# City no found. Skipping..
# Processing khonuu.
# City no found. Skipping..
# Processing tsihombe.
# City no found. Skipping..
# Processing damghan.
# Processing senanga.
# Processing narsaq.
# Processing cap malheureux.
# Processing berlevag.
# Processing juegang.
# Processing tra vinh.
# Processing tidore.
# City no found. Skipping..
# Processing bucerias.
# Processing mabaruma.
# Processing lethem.
# Processing tyulyachi.
# Processing sakaiminato.
# Processing nicoya.
# Processing saint-denis.
# Processing carbunari.
# Processing sao miguel do araguaia.
# Processing kauran.
# Processing bougouni.
# Processing magadan.
# Processing staryy oskol.
# Processing chicama.
# Processing talnakh.
# Processing andenes.
# City no found. Skipping..
# Processing shizunai.
# Processing varhaug.
# Processing nushki.
# Processing sentyabrskiy.
# City no found. Skipping..
# Processing moree.
# Processing kuli.
# Processing srikakulam.
# Processing tazmalt.
# Processing aklavik.
# Processing longlac.
# City no found. Skipping..
# Processing stepnyak.
# Processing gelibolu.
# Processing todos santos.
# Processing sangar.
# Processing san quintin.
# Processing quatre cocos.
# Processing tomohon.
# Processing agua prieta.
# Processing port moresby.
# Processing khuzdar.
# Processing chernyshevskiy.
# Processing nizhniy ingash.
# Processing yuzhno-yeniseyskiy.
# City no found. Skipping..
# Processing suntar.
# Processing paamiut.
# Processing emba.
# Processing broome.
# Processing flin flon.
# Processing port blair.
# Processing tombouctou.
# Processing kuytun.
# Processing bambous virieux.
# Processing mattru.
# Processing tautira.
# Processing lang son.
# Processing samarai.
# Processing yuza.
# Processing sitka.
# Processing kutum.
# Processing taloqan.
# Processing dorsten.
# Processing puerto colombia.
# Processing hami.
# Processing san luis.
# Processing slave lake.
# Processing cockburn harbour.
# City no found. Skipping..
# Processing dharmavaram.
# Processing guigue.
# Processing zafarabad.
# Processing bonwapitse.
# Processing enkhuizen.
# Processing minudasht.
# Processing orchard homes.
# Processing lensk.
# Processing whitianga.
# Processing pochutla.
# Processing aksu.
# Processing glenwood springs.
# Processing nouadhibou.
# Processing san andres.
# Processing weihai.
# Processing palmas bellas.
# Processing santiago del estero.
# Processing okha.
# Processing ahuimanu.
# Processing belmonte.
# Processing tawnat.
# City no found. Skipping..
# Processing pevek.
# Processing henties bay.
# Processing grande-riviere.
# City no found. Skipping..
# Processing satitoa.
# City no found. Skipping..
# Processing haines junction.
# Processing lexington park.
# Processing lublin.
# Processing terrasini.
# Processing korla.
# City no found. Skipping..
# Processing nantucket.
# Processing nabire.
# Processing zhangye.
# Processing brazzaville.
# Processing ponta delgada.
# Processing zyryanka.
# Processing pudozh.
# Processing sungurlu.
# Processing padre bernardo.
# City no found. Skipping..
# Processing ngunguru.
# Processing shimoda.
# Processing ostrovnoy.
# Processing izhevskoye.
# Processing mangrol.
# Processing thinadhoo.
# Processing beyneu.
# Processing vanimo.
# Processing alingsas.
# Processing vaitape.
# Processing russkaya polyana.
# Processing redencao.
# Processing sao filipe.
# Processing vostok.
# Processing fethiye.
# Processing palabuhanratu.
# City no found. Skipping..
# Processing camana.
# City no found. Skipping..
# Processing pyinmana.
# Processing bargal.
# City no found. Skipping..
# Processing timra.
# Processing umm lajj.
# Processing nago.
# Processing imbituba.
# Processing talcahuano.
# Processing pizhanka.
# Processing rawson.
# Processing tignere.
# Processing randvere.
# City no found. Skipping..
# Processing qaqortoq.
# Processing cabedelo.
# Processing alyangula.
# Processing kuche.
# City no found. Skipping..
# Processing brenham.
# Processing seguela.
# Processing ossora.
# Processing carnarvon.
# Processing baykit.
# Processing timaru.
# Processing wenchi.
# Processing tahta.
# City no found. Skipping..
# Processing bambanglipuro.
# Processing schaffhausen.
# Processing stelle.
# Processing fomboni.
# Processing muncar.
# Processing auki.
# Processing sampit.
# Processing nsunga.
# Processing kargil.
# Processing karlskoga.
# Processing perth.
# Processing palaiokhora.
# City no found. Skipping..
# Processing ust-omchug.
# Processing palmerston.
# Processing nalut.
# Processing iquique.
# Processing port macquarie.
# Processing havoysund.
# Processing warrnambool.
# Processing alice town.
# Processing homer.
# Processing oklahoma city.
# Processing meulaboh.
# Processing kedrovka.
# City no found. Skipping..
# Processing molina.
# Processing fairbanks.
# Processing rach gia.
# Processing artyk.
# City no found. Skipping..
# Processing seduva.
# Processing sotnikovo.
# Processing clarence town.
# Processing roches noires.
# City no found. Skipping..
# Processing marsabit.
# Processing gorno-chuyskiy.
# City no found. Skipping..
# Processing breves.
# Processing zhigansk.
# Processing kaele.

# %%
len(cities)
# Out:
# 627

# %%
len(cld)
# Out:
# 562

# %%
weather_dict = {
   "City": name,
    "Cloudiness": cld,
    "Country":contr,
    "Date": date,
    "Humidity": hum,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wd_sp
}

weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Torbay          90      CA  1569389565       100  47.66  -52.73
# 1           Avarua          47      CK  1569389540        73 -21.21 -159.78
# 2           Hasaki          20      JP  1569389605        54  35.73  140.83
# 3      New Norfolk          75      AU  1569389531        50 -42.78  147.06
# 4     San Patricio           0      PY  1569389969        82 -26.98  -56.83
# ..             ...         ...     ...         ...       ...    ...     ...
# 557  Clarence Town           0      AU  1569390282        42 -32.59  151.78
# 558       Marsabit           0      KE  1569390282        41   2.34   37.99
# 559         Breves          12      BR  1569390189        99  -1.68  -50.48
# 560       Zhigansk          63      RU  1569390282        57  66.77  123.37
# 561          Kaele         100      CM  1569390283        81  10.11   14.45
#
#      Max Temp  Wind Speed
# 0       46.00        9.17
# 1       71.60       10.29
# 2       91.00        8.05
# 3       57.00        8.05
# 4       60.47        4.79
# ..        ...         ...
# 557     66.99       14.99
# 558     84.23       21.36
# 559     71.63        2.21
# 560     44.81       14.67
# 561     76.85        4.05
#
# [562 rows x 9 columns]

# %% [markdown]
# # Temperature(F) vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o",color="m")

plt.title("Max Temperature vs. City Latitude (09/24/19)")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Humidity(%) vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o",color="y")

plt.title("Humidity vs. City Latitude (09/24/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Cloudiness vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o",color="c")

plt.title("Cloudiness vs. City Latitude (09/24/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Wind Speed vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o",color="g")

plt.title("Wind Speed vs. City Latitude (09/24/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Northern Hemisphere: Temperature, Humidity, Cloudiness, Wind Speed against Latitude

# %%
north_hem = weather_data.loc[(weather_data["Lat"] >= 0)]
north_hem = pd.DataFrame(north_hem)
north_hem
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Torbay          90      CA  1569389565       100  47.66  -52.73
# 2          Hasaki          20      JP  1569389605        54  35.73  140.83
# 6     Clarksville           1      US  1569389809        82  36.53  -87.36
# 9    Norman Wells          20      CA  1569389573        80  65.28 -126.83
# 10         Harper           1      US  1569390076        78  30.30  -99.24
# ..            ...         ...     ...         ...       ...    ...     ...
# 555        Seduva           0      LT  1569390281        86  55.77   23.77
# 556     Sotnikovo           6      RU  1569390282        45  51.88  107.48
# 558      Marsabit           0      KE  1569390282        41   2.34   37.99
# 560      Zhigansk          63      RU  1569390282        57  66.77  123.37
# 561         Kaele         100      CM  1569390283        81  10.11   14.45
#
#      Max Temp  Wind Speed
# 0       46.00        9.17
# 2       91.00        8.05
# 6       62.01        2.13
# 9       33.80        3.53
# 10      77.00       16.46
# ..        ...         ...
# 555     37.40        6.93
# 556     68.00        2.24
# 558     84.23       21.36
# 560     44.81       14.67
# 561     76.85        4.05
#
# [396 rows x 9 columns]

# %% [markdown]
# # Northern Hemisphere -->Temperature vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="m")
plt.plot(x_values,regress_values,"r-")
plt.title("Max Temperature vs. NH Latitude (09/24/19)")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
print(regress_values)
print(line_eq)
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# 0      56.059251
# 2      65.100646
# 6      64.494349
# 9      42.705573
# 10     69.215882
#          ...
# 555    49.912921
# 556    52.861038
# 558    90.405941
# 560    41.576346
# 561    84.517287
# Name: Lat, Length: 396, dtype: float64
# y = -0.76x +92.18
# The r-squared is: -0.8652133784473022

# %% [markdown]
# # Northern Hemisphere --> Humidity vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="y")
plt.plot(x_values,regress_values,"r-")
plt.title("Humidity vs. NH Latitude (09/24/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.09301445942293633

# %% [markdown]
# # Northern Hemisphere --> Cloudiness vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values,color="c")
plt.plot(x_values,regress_values,"r-")
plt.title("Cloudiness vs. NH Latitude (09/24/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(10,60),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.06152102403127146

# %% [markdown]
# # Northern Hemisphere --> Wind Speed vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color ="g")
plt.plot(x_values,regress_values,"r-")
plt.title("Wind Speed vs. NH Latitude (09/24/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(20,25),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.1730093256077083

# %% [markdown]
# # Southern Hemisphere: Temperature, Humidity, Cloudiness, Wind Speed against Latitude

# %%
south_hem = weather_data.loc[(weather_data["Lat"] < 0)]
south_hem = pd.DataFrame(south_hem)
south_hem
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1            Avarua          47      CK  1569389540        73 -21.21 -159.78
# 3       New Norfolk          75      AU  1569389531        50 -42.78  147.06
# 4      San Patricio           0      PY  1569389969        82 -26.98  -56.83
# 5       Port Alfred          35      ZA  1569389523        65 -33.59   26.89
# 7             Bluff           0      AU  1569389517        28 -23.58  149.07
# ..              ...         ...     ...         ...       ...    ...     ...
# 545  Port Macquarie          22      AU  1569390279        59 -31.43  152.91
# 547     Warrnambool          32      AU  1569390279        88 -38.38  142.48
# 552          Molina           0      CL  1569390281        93 -35.11  -71.28
# 557   Clarence Town           0      AU  1569390282        42 -32.59  151.78
# 559          Breves          12      BR  1569390189        99  -1.68  -50.48
#
#      Max Temp  Wind Speed
# 1       71.60       10.29
# 3       57.00        8.05
# 4       60.47        4.79
# 5       59.00        4.00
# 7       84.41       10.36
# ..        ...         ...
# 545     70.00       13.87
# 547     55.99       13.38
# 552     51.80        1.63
# 557     66.99       14.99
# 559     71.63        2.21
#
# [166 rows x 9 columns]

# %% [markdown]
# # Southern Hemisphere -->Temperature vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="m")
plt.plot(x_values,regress_values,"r-")
plt.title("Max Temperature vs. SH Latitude (09/24/19)")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
print(regress_values)
print(line_eq)
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# 1      67.612469
# 3      53.350274
# 4      63.797316
# 5      59.426750
# 7      66.045413
#          ...
# 545    60.854953
# 547    56.259577
# 552    58.421718
# 557    60.087955
# 559    80.525806
# Name: Lat, Length: 166, dtype: float64
# y = 0.66x +81.64
# The r-squared is: 0.7331871637628993

# %% [markdown]
# # Southern Hemisphere --> Humidity vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="y")
plt.plot(x_values,regress_values,"r-")
plt.title("Humidity vs. SH Latitude (09/24/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.13211717510375037

# %% [markdown]
# # Southern Hemisphere --> Cloudiness vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values,color="c")
plt.plot(x_values,regress_values,"r-")
plt.title("Cloudiness vs. SH Latitude (09/24/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.024086458033019044

# %% [markdown]
# # Southern Hemisphere --> Wind Speed vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color ="g")
plt.plot(x_values,regress_values,"r-")
plt.title("Wind Speed vs. SH Latitude (09/24/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.14808388807078673
