# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from scipy import stats

# %%
from api_keys import weather_api_key
from citipy import citipy

# %% [markdown]
# # General Cities List

# %%
output_data_file = "output_data/cities.csv"
cities_wth = pd.read_csv(output_data_file)
cities_wth
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]

# %%
lat_range =(-90,90)
lng_range =(-180,180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.00, high=90.00, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 599

# %% [markdown]
# # API Call

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

#city_name = cities_wth["City"].tolist()

lat = []
lng = []
hum = []
contr = []
name = []
date = []
max_temp = []
wd_sp = []
cld = []

#print(json.dumps(response,indent=4))

for city in cities:
    try:
        print(f"Processing {city}.")
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        hum.append(response['main']['humidity'])
        contr.append(response['sys']['country'])
        name.append(response['name'])
        date.append(response['dt'])
        max_temp.append(response['main']['temp_max'])
        wd_sp.append(response['wind']['speed'])
        cld.append(response['clouds']['all'])
    except (KeyError):
        print("City no found. Skipping..")
# Out:
# Processing bredasdorp.
# Processing nakhon si thammarat.
# Processing busselton.
# Processing ponta do sol.
# Processing moose factory.
# Processing waipawa.
# Processing mataura.
# Processing vila franca do campo.
# Processing tuktoyaktuk.
# Processing vaini.
# Processing taolanaro.
# City no found. Skipping..
# Processing kodiak.
# Processing tiksi.
# Processing amderma.
# City no found. Skipping..
# Processing saldanha.
# Processing kulhudhuffushi.
# Processing rikitea.
# Processing kapaa.
# Processing sarangani.
# Processing severo-kurilsk.
# Processing dikson.
# Processing aksarka.
# Processing saint george.
# Processing airai.
# Processing rawatsar.
# Processing gambela.
# Processing bluff.
# Processing hobart.
# Processing nizhneyansk.
# City no found. Skipping..
# Processing nikolskoye.
# Processing cidreira.
# Processing vila velha.
# Processing krasnyy chikoy.
# Processing padang.
# Processing mys shmidta.
# City no found. Skipping..
# Processing hermanus.
# Processing norman wells.
# Processing atuona.
# Processing rocha.
# Processing aklavik.
# Processing grindavik.
# Processing ostrovnoy.
# Processing panindicuaro.
# Processing husavik.
# Processing provideniya.
# Processing touros.
# Processing port elizabeth.
# Processing jamestown.
# Processing butaritari.
# Processing tasiilaq.
# Processing ushuaia.
# Processing rawson.
# Processing saint-philippe.
# Processing at-bashi.
# Processing rurrenabaque.
# Processing saleaula.
# City no found. Skipping..
# Processing puerto ayora.
# Processing punta arenas.
# Processing chuy.
# Processing lavrentiya.
# Processing torbay.
# Processing lebu.
# Processing isangel.
# Processing thompson.
# Processing albany.
# Processing mongomo.
# Processing barrow.
# Processing carnarvon.
# Processing hihifo.
# City no found. Skipping..
# Processing mahroni.
# Processing paita.
# Processing cape town.
# Processing yulara.
# Processing tsihombe.
# City no found. Skipping..
# Processing hithadhoo.
# Processing port alfred.
# Processing cervo.
# Processing myitkyina.
# Processing port hardy.
# Processing bonthe.
# Processing bargal.
# City no found. Skipping..
# Processing zakamensk.
# Processing sioux lookout.
# Processing ust-ishim.
# Processing fairbanks.
# Processing havre-saint-pierre.
# Processing caraballeda.
# Processing valdez.
# Processing warrington.
# Processing christchurch.
# Processing vinh yen.
# Processing luderitz.
# Processing castro.
# Processing samalaeulu.
# City no found. Skipping..
# Processing ikot ekpene.
# Processing himora.
# City no found. Skipping..
# Processing portland.
# Processing san patricio.
# Processing lermontovka.
# Processing xining.
# Processing tabiauea.
# City no found. Skipping..
# Processing mount isa.
# Processing ryotsu.
# Processing meulaboh.
# Processing masaguisi.
# Processing sattahip.
# Processing maarianhamina.
# City no found. Skipping..
# Processing pacific grove.
# Processing makakilo city.
# Processing codrington.
# Processing charters towers.
# Processing pilar.
# Processing victoria.
# Processing hervey bay.
# Processing miranda de ebro.
# Processing korla.
# City no found. Skipping..
# Processing zhigansk.
# Processing katsuura.
# Processing hami.
# Processing avarua.
# Processing nouadhibou.
# Processing guymon.
# Processing palmer.
# Processing te anau.
# Processing upernavik.
# Processing flinders.
# Processing barcelona.
# Processing teguldet.
# Processing alofi.
# Processing mao.
# Processing ust-maya.
# Processing bengkulu.
# City no found. Skipping..
# Processing coquimbo.
# Processing pisco.
# Processing plettenberg bay.
# Processing loja.
# Processing cockburn town.
# Processing esperance.
# Processing new norfolk.
# Processing el paujil.
# Processing verkhnyaya toyma.
# Processing kahului.
# Processing scortoasa.
# Processing pevek.
# Processing kirakira.
# Processing parker.
# Processing pasighat.
# Processing mackay.
# Processing linxia.
# Processing seoul.
# Processing bushehr.
# Processing broken hill.
# Processing arraial do cabo.
# Processing sentyabrskiy.
# City no found. Skipping..
# Processing hambantota.
# Processing illoqqortoormiut.
# City no found. Skipping..
# Processing mar del plata.
# Processing hilo.
# Processing banjar.
# Processing bagdarin.
# Processing changde.
# Processing makaha.
# Processing la ronge.
# Processing clyde river.
# Processing georgetown.
# Processing jumla.
# Processing chokurdakh.
# Processing ust-kamchatsk.
# City no found. Skipping..
# Processing gurupa.
# City no found. Skipping..
# Processing barentsburg.
# City no found. Skipping..
# Processing shimoda.
# Processing lerwick.
# Processing port augusta.
# Processing rochegda.
# Processing kandrian.
# Processing bethel.
# Processing olafsvik.
# City no found. Skipping..
# Processing coihaique.
# Processing ancud.
# Processing tubruq.
# City no found. Skipping..
# Processing menongue.
# Processing wokha.
# Processing marzuq.
# Processing karratha.
# Processing brodnica.
# Processing pokaran.
# Processing klaksvik.
# Processing immokalee.
# Processing jardinopolis.
# Processing gornopravdinsk.
# Processing san andres.
# Processing griffin.
# Processing peniche.
# Processing mount gambier.
# Processing betanzos.
# Processing pokhara.
# Processing bilma.
# Processing udachnyy.
# Processing avera.
# Processing vanavara.
# Processing cabo san lucas.
# Processing lugovoy.
# Processing kruisfontein.
# Processing chittaurgarh.
# Processing dawei.
# Processing vestmannaeyjar.
# Processing norfolk.
# Processing kostomuksha.
# Processing anshun.
# Processing tornio.
# Processing urucui.
# Processing mazagao.
# Processing bondo.
# Processing mwene-ditu.
# Processing progreso.
# Processing jawhar.
# Processing oriximina.
# Processing port arthur.
# Processing longyearbyen.
# Processing matay.
# Processing yellowknife.
# Processing sola.
# Processing fortuna.
# Processing urengoy.
# Processing dubbo.
# Processing sinop.
# Processing hofn.
# Processing halifax.
# Processing kambove.
# Processing mahebourg.
# Processing qena.
# Processing richards bay.
# Processing maceio.
# Processing ondorhaan.
# City no found. Skipping..
# Processing sinnamary.
# Processing prince rupert.
# Processing toliary.
# City no found. Skipping..
# Processing barentu.
# Processing hurghada.
# City no found. Skipping..
# Processing tilichiki.
# Processing pochutla.
# Processing ereymentau.
# Processing shirokiy.
# Processing hobyo.
# Processing gandia.
# Processing myra.
# Processing samusu.
# City no found. Skipping..
# Processing constitucion.
# Processing zemio.
# Processing fort nelson.
# Processing khash.
# Processing port-cartier.
# Processing eyl.
# Processing bathsheba.
# Processing north bend.
# Processing catia la mar.
# Processing motygino.
# Processing ribeira grande.
# Processing kavieng.
# Processing belushya guba.
# City no found. Skipping..
# Processing tuy hoa.
# Processing aneza.
# Processing beringovskiy.
# Processing vaitupu.
# City no found. Skipping..
# Processing pimentel.
# Processing roma.
# Processing araouane.
# Processing encamp.
# Processing sohag.
# Processing talnakh.
# Processing berdigestyakh.
# Processing east london.
# Processing nanortalik.
# Processing marienburg.
# Processing tuatapere.
# Processing hasaki.
# Processing quatre cocos.
# Processing puri.
# Processing cajaruro.
# Processing san ramon.
# Processing svay rieng.
# Processing svetlyy.
# City no found. Skipping..
# Processing inhambane.
# Processing lakatoro.
# Processing wangqing.
# Processing vysokovsk.
# Processing roald.
# Processing pandharpur.
# Processing sao sebastiao.
# Processing sumbawa.
# City no found. Skipping..
# Processing leninskoye.
# Processing qaanaaq.
# Processing sao filipe.
# Processing rabo de peixe.
# Processing kibaya.
# Processing attawapiskat.
# City no found. Skipping..
# Processing broome.
# Processing talas.
# Processing saint andrews.
# Processing peleduy.
# Processing komsomolskiy.
# Processing los llanos de aridane.
# Processing axim.
# Processing khatanga.
# Processing qandahar.
# City no found. Skipping..
# Processing melilla.
# Processing boa vista.
# Processing kidal.
# Processing marrakesh.
# Processing shimminato.
# Processing chadiza.
# Processing borogontsy.
# Processing hovd.
# Processing haines junction.
# Processing port blair.
# Processing santa lucia.
# Processing mehamn.
# Processing taksimo.
# Processing magdagachi.
# Processing porbandar.
# Processing geraldton.
# Processing bridgend.
# Processing tateyama.
# Processing port hawkesbury.
# Processing hokitika.
# Processing baruun-urt.
# Processing sabang.
# Processing port lincoln.
# Processing bubaque.
# Processing santa cruz cabralia.
# Processing ladario.
# Processing sitka.
# Processing inirida.
# Processing lompoc.
# Processing pavilosta.
# Processing kizukuri.
# Processing carballo.
# Processing mullaitivu.
# City no found. Skipping..
# Processing lagoa.
# Processing cabedelo.
# Processing road town.
# Processing oranjemund.
# Processing khani.
# Processing marsa matruh.
# Processing bambous virieux.
# Processing clovis.
# Processing kholodnyy.
# Processing rio gallegos.
# Processing kodinsk.
# Processing palmerston.
# Processing auki.
# Processing luanda.
# Processing tomatlan.
# Processing guerrero negro.
# Processing caravelas.
# Processing tumannyy.
# City no found. Skipping..
# Processing yeniseysk.
# Processing kuvandyk.
# Processing tual.
# Processing ornskoldsvik.
# Processing powell river.
# Processing byron bay.
# Processing toba.
# Processing madang.
# Processing turukhansk.
# Processing san cristobal.
# Processing lianzhou.
# Processing smithers.
# Processing jardim.
# Processing tessalit.
# Processing sistranda.
# Processing panubigan.
# Processing mehran.
# Processing salinopolis.
# Processing krasnogorodsk.
# Processing gogrial.
# City no found. Skipping..
# Processing mapiri.
# Processing acapulco.
# Processing beidao.
# Processing salalah.
# Processing srednekolymsk.
# Processing toora-khem.
# Processing gizo.
# Processing ahipara.
# Processing evensk.
# Processing saskylakh.
# Processing skjeberg.
# Processing yazman.
# Processing narsaq.
# Processing dingli.
# Processing pelym.
# Processing burnie.
# Processing hanna.
# Processing saint-augustin.
# Processing kargasok.
# Processing kapiri mposhi.
# Processing zhanakorgan.
# Processing sambava.
# Processing faya.
# Processing ixtapa.
# Processing celestun.
# Processing grand river south east.
# City no found. Skipping..
# Processing chumikan.
# Processing lasa.
# Processing barra patuca.
# Processing lumphat.
# Processing piet retief.
# Processing sidmouth.
# Processing san rafael.
# Processing taltal.
# Processing pingyi.
# City no found. Skipping..
# Processing ayan.
# Processing maningrida.
# Processing wahran.
# City no found. Skipping..
# Processing aktash.
# City no found. Skipping..
# Processing georgiyevskoye.
# Processing dudinka.
# Processing acari.
# Processing ingham.
# Processing revda.
# Processing porto novo.
# Processing tir pol.
# City no found. Skipping..
# Processing palabuhanratu.
# City no found. Skipping..
# Processing dibulla.
# Processing umm ruwabah.
# City no found. Skipping..
# Processing skjervoy.
# Processing gubkinskiy.
# Processing kanye.
# Processing oranjestad.
# Processing harnosand.
# Processing kuopio.
# Processing champerico.
# Processing sandwick.
# Processing fernie.
# Processing dmitrov.
# Processing tari.
# Processing arlit.
# Processing luba.
# Processing ambodifototra.
# City no found. Skipping..
# Processing tautira.
# Processing itarema.
# Processing cabo rojo.
# Processing morondava.
# Processing lampa.
# Processing kashi.
# City no found. Skipping..
# Processing dunmore town.
# Processing mandalgovi.
# Processing tura.
# Processing leningradskiy.
# Processing sungaipenuh.
# Processing tres arroyos.
# Processing otacilio costa.
# Processing kununurra.
# Processing matara.
# Processing saint-michel-des-saints.
# Processing buala.
# Processing kendari.
# Processing sisimiut.
# Processing kalmunai.
# Processing gravdal.
# Processing ilulissat.
# Processing kirovskiy.
# Processing banda aceh.
# Processing salamiyah.
# Processing butwal.
# Processing honningsvag.
# Processing itoman.
# Processing taoudenni.
# Processing zhuanghe.
# Processing jiangyou.
# Processing nha trang.
# Processing kasempa.
# Processing naze.
# Processing lichinga.
# Processing ileza.
# Processing tonstad.
# Processing sakakah.
# City no found. Skipping..
# Processing senneterre.
# Processing malanje.
# Processing puerto asis.
# Processing vesele.
# Processing namibe.
# Processing mehar.
# Processing sur.
# Processing north platte.
# Processing laguna.
# Processing aykhal.
# Processing nantucket.
# Processing sao joao da barra.
# Processing durant.
# Processing verkhnyaya inta.
# Processing edd.
# Processing ruidoso.
# Processing kaili.
# Processing belgrade.
# Processing tunduru.
# City no found. Skipping..
# Processing deputatskiy.
# Processing kingman.
# Processing antalaha.
# Processing goderich.
# Processing kutum.
# Processing yantal.
# Processing cherskiy.
# Processing miranda.
# Processing vallenar.
# Processing lata.
# Processing eskasem.
# City no found. Skipping..
# Processing kamenskoye.
# City no found. Skipping..
# Processing khor.
# Processing jilin.
# Processing shenjiamen.
# Processing aitape.
# Processing coria.
# Processing kopayhorod.
# Processing lensk.
# Processing zapolyarnyy.
# Processing kasongo-lunda.
# Processing pingliang.
# Processing neiafu.
# Processing blagoyevo.
# Processing meridian.
# Processing manta.
# Processing adrar.
# Processing jambi.
# Processing solnechnyy.
# Processing iqaluit.
# Processing sabinas hidalgo.
# Processing lolua.
# City no found. Skipping..
# Processing uusikaupunki.
# Processing matamoros.
# Processing kavaratti.
# Processing vaitape.
# Processing berbera.
# City no found. Skipping..
# Processing doctor pedro p. pena.
# City no found. Skipping..
# Processing bur gabo.
# City no found. Skipping..
# Processing neftcala.
# Processing longlac.
# City no found. Skipping..
# Processing jalu.
# Processing ntungamo.
# Processing kangly.
# Processing marawi.
# Processing yanan.
# City no found. Skipping..
# Processing san jose.
# Processing mogocha.
# Processing tymovskoye.
# Processing jiuquan.
# Processing kaitangata.
# Processing severnyy.
# City no found. Skipping..
# Processing bairiki.
# City no found. Skipping..
# Processing faanui.
# Processing tecoanapa.
# Processing okhotsk.
# Processing leshukonskoye.
# Processing dubenskiy.
# City no found. Skipping..
# Processing chara.
# Processing alakurtti.
# Processing elat.
# Processing souillac.
# Processing belyy yar.
# Processing meyungs.
# City no found. Skipping..
# Processing vanimo.
# Processing cootamundra.
# Processing manaus.
# Processing ye.
# City no found. Skipping..
# Processing nizhniy kuranakh.
# Processing cascais.
# Processing barstow.
# Processing alice springs.
# Processing kailua.
# Processing sharlyk.
# Processing luwuk.
# Processing la sarre.
# Processing vardo.
# Processing skibbereen.
# Processing nalut.
# Processing maldonado.
# Processing maxixe.
# Processing dolores.
# Processing fort frances.
# Processing necochea.
# Processing santa maria.
# Processing paamiut.
# Processing marsh harbour.
# Processing altamont.
# Processing noumea.
# Processing sheopur.
# Processing la maddalena.
# Processing sorvag.
# City no found. Skipping..
# Processing phrai bung.
# City no found. Skipping..
# Processing turtas.
# Processing hunza.
# City no found. Skipping..
# Processing estevan.
# Processing surt.
# Processing cayenne.
# Processing louisbourg.
# City no found. Skipping..
# Processing tahta.
# City no found. Skipping..
# Processing dalvik.
# Processing khalkhal.
# Processing ambilobe.

# %%
len(cities)
# Out:
# 599

# %%
len(cld)
# Out:
# 536

# %%
weather_dict = {
   "City": name,
    "Cloudiness": cld,
    "Country":contr,
    "Date": date,
    "Humidity": hum,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wd_sp
}

weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#                     City  Cloudiness Country        Date  Humidity    Lat  \
# 0             Bredasdorp          76      ZA  1570045812        82 -34.53
# 1    Nakhon Si Thammarat         100      TH  1570045881        90   8.43
# 2              Busselton          76      AU  1570045812        69 -33.64
# 3           Ponta do Sol           0      BR  1570045871        44 -20.63
# 4          Moose Factory          90      CA  1570045657        80  51.26
# ..                   ...         ...     ...         ...       ...    ...
# 531                 Surt           0      LY  1570045819        76  31.21
# 532              Cayenne          86      GF  1570046058        62   4.94
# 533               Dalvik          75      SE  1570046058        93  57.79
# 534             Khalkhal           0      IR  1570046059        74  37.62
# 535             Ambilobe          51      MG  1570046059        68 -13.19
#
#         Lng  Max Temp  Wind Speed
# 0     20.04     59.00        5.82
# 1     99.96     73.88        2.17
# 2    115.35     55.99        9.40
# 3    -46.00     78.56        4.27
# 4    -80.61     41.00        6.93
# ..      ...       ...         ...
# 531   16.59     78.58       16.15
# 532  -52.33     87.80       13.87
# 533   14.13     45.00       10.29
# 534   48.53     45.94        0.89
# 535   49.05     75.57        6.82
#
# [536 rows x 9 columns]

# %%
weather_data.to_csv("Weather_Cities.csv",encoding="utf-8", index=False)

# %% [markdown]
# # Temperature(F) vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o",color="m")

plt.title("Max Temperature vs. City Latitude (10/02/19)")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Images/Max Temperature vs City Latitude")
plt.show()

# %% [markdown]
# # Humidity(%) vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o",color="y")

plt.title("Humidity vs. City Latitude (10/02/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Images/Humidity vs City Latitude.png")
plt.show()

# %% [markdown]
# # Cloudiness vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o",color="c")

plt.title("Cloudiness vs. City Latitude (10/02/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Images/Cloudiness vs City Latitude.png")
plt.show()

# %% [markdown]
# # Wind Speed vs. Latitude

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o",color="g")

plt.title("Wind Speed vs. City Latitude (10/02/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Images/Wind Speed vs City Latitude.png")
plt.show()

# %% [markdown]
# # Northern Hemisphere: Temperature, Humidity, Cloudiness, Wind Speed against Latitude

# %%
north_hem = weather_data.loc[(weather_data["Lat"] >= 0)]
north_hem = pd.DataFrame(north_hem)
north_hem

# %% [markdown]
# # Northern Hemisphere -->Temperature vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="m")
plt.plot(x_values,regress_values,"r-")
plt.title("Max Temperature vs. NH Latitude (09/24/19)")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
print(regress_values)
print(line_eq)
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Max Temperature vs. NH Latitude (09/24/19)")
plt.show()

# %% [markdown]
# # Northern Hemisphere --> Humidity vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="y")
plt.plot(x_values,regress_values,"r-")
plt.title("Humidity vs. NH Latitude (09/24/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Humidity vs. NH Latitude (09/24/19)")
plt.show()

# %% [markdown]
# # Northern Hemisphere --> Cloudiness vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values,color="c")
plt.plot(x_values,regress_values,"r-")
plt.title("Cloudiness vs. NH Latitude (09/24/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(10,60),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Cloudiness vs. NH Latitude (09/24/19)")
plt.show()

# %% [markdown]
# # Northern Hemisphere --> Wind Speed vs. Latitude

# %%
x_values = north_hem['Lat']
y_values = north_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color ="g")
plt.plot(x_values,regress_values,"r-")
plt.title("Wind Speed vs. NH Latitude (09/24/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(20,25),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Wind Speed vs. NH Latitude (09/24/19)")
plt.show()

# %% [markdown]
# # Southern Hemisphere: Temperature, Humidity, Cloudiness, Wind Speed against Latitude

# %%
south_hem = weather_data.loc[(weather_data["Lat"] < 0)]
south_hem = pd.DataFrame(south_hem)
south_hem

# %% [markdown]
# # Southern Hemisphere -->Temperature vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="m")
plt.plot(x_values,regress_values,"r-")
plt.title("Max Temperature vs. SH Latitude (09/24/19)")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
print(regress_values)
print(line_eq)
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Max Temperature vs. SH Latitude (09/24/19)")
plt.show()

# %% [markdown]
# # Southern Hemisphere --> Humidity vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color="y")
plt.plot(x_values,regress_values,"r-")
plt.title("Humidity vs. SH Latitude (09/24/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Humidity vs. SH Latitude (09/24/19)")
plt.show()

# %% [markdown]
# # Southern Hemisphere --> Cloudiness vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values,color="c")
plt.plot(x_values,regress_values,"r-")
plt.title("Cloudiness vs. SH Latitude (09/24/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Cloudiness vs. SH Latitude (09/24/19)")
plt.show()

# %% [markdown]
# # Southern Hemisphere --> Wind Speed vs. Latitude

# %%
x_values = south_hem['Lat']
y_values = south_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values, color ="g")
plt.plot(x_values,regress_values,"r-")
plt.title("Wind Speed vs. SH Latitude (09/24/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.savefig("../Images/Wind Speed vs. SH Latitude (09/24/19)")
plt.show()
